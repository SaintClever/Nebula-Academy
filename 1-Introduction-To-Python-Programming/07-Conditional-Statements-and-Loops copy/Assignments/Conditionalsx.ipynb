# %% [markdown]
# # If/Else Statements Practice
#
# ## Question 1
#
# Write a program that checks if a number is positive or negative. If the number is positive, print 'Positive', otherwise print 'Negative' (or zero).

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 2
#
# Write a program that determines whether a given number is even or odd. If the number is even, print 'Even', otherwise print 'Odd'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 3
#
# Write a program that checks if a given year is a leap year. If the year is a leap year, print 'Leap year', otherwise print 'Not a leap year'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 4
#
# Write a program that determines the largest of three numbers. Print the largest number.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 5
#
# Write a program that checks if a given character is a vowel or a consonant. If the character is a vowel, print 'Vowel', otherwise print 'Consonant'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 6
#
# Write a program that calculates the grade based on a given percentage. The program should print 'A' for percentages greater than or equal to 90, 'B' for percentages between 80 and 89, 'C' for percentages between 70 and 79, 'D' for percentages between 60 and 69, and 'F' for percentages less than 60.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 7
#
# Write a program that checks if a given number is a perfect square. If the number is a perfect square, print 'Perfect square', otherwise print 'Not a perfect square'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 8
#
# Write a program that checks if a given number is divisible by both 2 and 3. If the number is divisible by both, print 'Divisible by 2 and 3', otherwise print 'Not divisible by 2 and 3'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 9
#
# Write a program that determines the quadrant of a given point (x, y). The program should print 'Quadrant 1' if both x and y are positive, 'Quadrant 2' if x is negative and y is positive, 'Quadrant 3' if both x and y are negative, and 'Quadrant 4' if x is positive and y is negative.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 10
#
# Write a program that determines if a given year is a leap year. However, if the year is divisible by 100, it should only be considered a leap year if it is also divisible by 400. Print 'Leap year' if it is a leap year, and 'Not a leap year' otherwise.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 11
#
# Write a program that checks if a given string is a palindrome. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward. If the string is a palindrome, print 'Palindrome', otherwise print 'Not a palindrome'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 12
#
# Write a program that determines the roots of a quadratic equation given the coefficients a, b, and c. If the discriminant (b^2 - 4ac) is positive, print 'Two real roots', if it is zero, print 'One real root', and if it is negative, print 'No real roots'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 13
#
# Write a program that determines the type of a triangle based on the lengths of its sides. The program should print 'Equilateral' if all sides are equal, 'Isosceles' if two sides are equal, and 'Scalene' if no sides are equal.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 14
#
# Write a program that determines if a given year is a century year. A century year is a year that is divisible by 100. If the year is a century year, print 'Century year', otherwise print 'Not a century year'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 15
#
# Write a program that checks if a given string is a palindrome. Ignore whitespace and consider uppercase and lowercase letters as equal. If the string is a palindrome, print 'Palindrome', otherwise print 'Not a palindrome'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 16
#
# Write a program that determines the day of the week based on a given date (day, month, year). Assume the date is valid. The program should print the day of the week in the format 'Monday', 'Tuesday', etc.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 17
#
# Write a program that determines the discount percentage based on a given purchase amount. If the purchase amount is greater than or equal to $500, apply a 20% discount. If the purchase amount is between $200 and $499.99, apply a 10% discount. Otherwise, apply a 5% discount. Print the discount percentage.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 18
#
# Write a program that determines if a given number is a prime number. A prime number is a number greater than 1 that has no positive divisors other than 1 and itself. If the number is prime, print 'Prime number', otherwise print 'Not a prime number'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 19
#
# Write a program that checks if a given string is a pangram. A pangram is a sentence that contains every letter of the alphabet at least once. If the string is a pangram, print 'Pangram', otherwise print 'Not a pangram'.

# %%
# Your Solution Here ❌

# %% [markdown]
# ## Question 20
#
# Write a program that checks if a given number is a power of two. If the number is a power of two, print 'Power of two', otherwise print 'Not a power of two'.

# %%
# Your Solution Here ❌
