# %% [markdown]
# # The Great Python Adventure
# ### Variables and Operators MadLib

# %% [markdown]
# Complete the following codeblock by assigning all of these variables with appropriate values according to their names/comments. After you've finished, use the final code block to print out the completed madlib!

# %%
# # Please replace each undefined variable with appropriate data as described in the comments

# # A noun (singular) - String
# noun1 = None # TODO: Replace None with a noun as a string.

# # A boolean value
# bool_val = None # TODO: Replace None with a Boolean value (True or False).

# # A list of 2 names - List of strings
# names = None # TODO: Replace None with a list of two names as strings.

# # An adjective describing a building - String
# building_adjective = None # TODO: Replace None with an adjective describing a building as a string.

# # A type of food (singular) - String
# food1 = None # TODO: Replace None with a type of food as a string.

# A tuple of types of food - Tuple
# food_tuple = None # TODO: Replace None with a set of distinct types of food as strings.

# # A verb (past tense) - String
# verb_past1 = None # TODO: Replace None with a past tense verb as a string.

# # A verb (present tense) - String
# verb_present1 = None # TODO: Replace None with a present tense verb as a string.

# # A number - Integer
# number1 = None # TODO: Replace None with a number (integer).

# # A floating-point number - Float
# float_num = None # TODO: Replace None with a floating point number.

# # A dictionary mapping adjectives to colors - Dictionary
# color_dict = None # TODO: Replace None with a dictionary mapping adjectives to colors.

# # A tuple of two types of animals - Tuple
# animal_tuple = None # TODO: Replace None with a tuple of two types of animals as strings.

# # A sound - String
# sound1 = None # TODO: Replace None with a sound as a string.

# # A feeling - String
# feeling1 = None # TODO: Replace None with a feeling as a string.

# # A geographical location - String
# location1 = None # TODO: Replace None with a geographical location as a string.

# # A mode of transportation - String
# transport1 = None # TODO: Replace None with a mode of transportation as a string.

# # A type of weather - String
# weather1 = None # TODO: Replace None with a type of weather as a string.

# # A time of day - String
# time_of_day1 = None # TODO: Replace None with a time of day as a string.

# # A body part - String
# body_part1 = None # TODO: Replace None with a body part as a string.

# # A language - String
# language1 = None # TODO: Replace None with a language as a string.

# %%
# Please replace each undefined variable with appropriate data as described in the comments

# A noun (singular) - String
noun1 = 'dog'

# A boolean value
bool_val = True

# A list of 2 names - List of strings
names = ['John', 'Jane']

# An adjective describing a building - String
building_adjective = 'tall'

# A type of food (singular) - String
food1 = 'pizza'

# A tuple of types of food - tuple
food_tuple = ('pizza', 'pasta')

# A verb (past tense) - String
verb_past1 = 'ate'

# A verb (present tense) - String
verb_present1 = 'swim'

# A number - Integer
number1 = 32

# A floating-point number - Float
float_num = 13.8

# A dictionary mapping adjectives to the colors red and blue - Dictionary
color_dict = {'red': 'hot', 'blue': 'cold'}

# A tuple of two types of animals - Tuple
animal_tuple = ('dog', 'cat')

# A sound - String
sound1 = 'meow'

# A feeling - String
feeling1 = 'happy'

# A geographical location - String
location1 = 'New York'

# A mode of transportation - String
transport1 = 'car'

# A type of weather - String
weather1 = 'rainy'

# A time of day - String
time_of_day1 = 'morning'

# A body part - String
body_part1 = 'hand'

# A language - String
language1 = 'English'

# %%
print(f"In the world of Pythonlandia, a brave student named {names[0]} found a {noun1} that would forever change their life.")
print(f"Did the {noun1} possess magical powers?")
if (bool_val): print("Aye, it did!")
else: print("No, it did not.")

print(f"On a {weather1} day in {location1}, {names[0]} and their sidekick {names[1]} encountered a {building_adjective} building.")
print(f"In the building, they found a mysterious meal. It was none other than {food1}. But wait! There were also different types of foods: {' and '.join(food_tuple)}.")

print(f"{names[0]} {verb_past1} in surprise. Their sidekick {names[1]} began to {verb_present1} the food.")
print(f"Then, a sudden {sound1} echoed around them. They both felt a strong sense of {feeling1}, but they lept to their feer")
print(f"Quick grab the {food1}! {names[1].capitalize()} exclaimed. They knew that the {food1} would help them on their journey to defeat the {color_dict['red']} {animal_tuple[0]} and {color_dict['blue']} {animal_tuple[1]}.")

print(f"In Pythonlandia, the number {number1} is considered sacred and the exact number of steps needed to reach the top of the building.")
print(f"Each step was {float_num} feet high, a peculiar measurement for this fantastical land.")

print(f"On their journey, they saw creatures of all kinds, specifically a {animal_tuple[0]} and a {animal_tuple[1]}, each possessing qualities beyond the ordinary.")
print(f"The {animal_tuple[0]} was {color_dict['red']} and the {animal_tuple[1]} was {color_dict['blue']}.")

print(f"Pythonlandia was a world of wonder, filled with the noise of {language1} being spoken and the {time_of_day1} sky full of sparkles.")
print(f"In the end, {names[0]} and {names[1]} took a {transport1}, returning home with the magical {noun1} firmly in {names[0]}'s {body_part1}.")

print(f"Their epic journey had come to an end, but their adventure in the realm of Python continues, for they had received the magical {noun1} and now had the power to decipher the language of the codes!")
# Out:
# In the world of Pythonlandia, a brave student named John found a dog that would forever change their life.
# Did the dog possess magical powers?
# Aye, it did!
# On a rainy day in New York, John and their sidekick Jane encountered a tall building.
# In the building, they found a mysterious meal. It was none other than pizza. But wait! There were also different types of foods: pizza and pasta.
# John ate in surprise. Their sidekick Jane began to swim the food.
# Then, a sudden meow echoed around them. They both felt a strong sense of happy, but they lept to their feer
# Quick grab the pizza! Jane exclaimed. They knew that the pizza would help them on their journey to defeat the hot dog and  cold cat.
# In Pythonlandia, the number 32 is considered sacred and the exact number of steps needed to reach the top of the building.
# Each step was 13.8 feet high, a peculiar measurement for this fantastical land.
# ...
